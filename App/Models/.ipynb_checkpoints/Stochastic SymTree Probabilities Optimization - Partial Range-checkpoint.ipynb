# %%
import ABCHelpers
from ABCHelpers import *

# %%
modelName = 'Young_Shrub'

# %%
# Some PyABC magic to get our set of parameters
from pyabc import (ABCSMC, Distribution, RV, MultivariateNormalTransition)
import scipy as sp
import scipy.stats as st
import tempfile
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
metrics = {
    'w':       (0.2, 1.5),
    'decay':   (0.5, 1.0),
    'slash':   (0, 90),
    'slash_r': (0, 50),
    'plus':    (0, 180),
    'plus_r':  (0, 50)
}

# %%
prior = Distribution(slash   =RV("uniform", 0, 90), 
                     slash_r =RV("uniform", 0, 50),
                     plus    =RV("uniform", 0, 180),
                     plus_r  =RV("uniform", 0, 50),
                     decay   =RV("uniform", 0.5, 1.0),
                     w       =RV("uniform", 0.2, 1.5),                     
                    )

# %%
abc = ABCSMC(model, prior, distance)

# %%
db_path = ("sqlite:///" + os.path.join(tempfile.gettempdir(), "test.db"))

# %%
target = model({})

# %%
abc.new(db_path, target)
# Out:
# INFO:History:Start <ABCSMC(id=15, start_time=2019-02-24 15:53:12.715672, end_time=None)>
# INFO:Epsilon:initial epsilon is 25.5700696817915
# 15

# %%
history = abc.run(minimum_epsilon=1.0, max_nr_populations=15)
# Out:
# INFO:ABC:t:0 eps:25.5700696817915
# INFO:ABC:t:1 eps:17.52877060527192
# INFO:ABC:t:2 eps:11.59016342167043
# INFO:ABC:t:3 eps:8.682977900656205
# INFO:ABC:t:4 eps:8.296458002527903
# INFO:ABC:t:5 eps:6.9485649115584085
# INFO:ABC:t:6 eps:5.956923160562545
# INFO:ABC:t:7 eps:5.883757810876039
# INFO:ABC:t:8 eps:5.3853966732731875
# INFO:ABC:t:9 eps:4.68141236881266
# INFO:ABC:t:10 eps:4.14843250461712
# INFO:ABC:t:11 eps:3.665767471423583
# INFO:ABC:t:12 eps:3.4136560385706365
# INFO:ABC:t:13 eps:2.982461492239093
# INFO:ABC:t:14 eps:2.6871667135374246
# INFO:History:Done <ABCSMC(id=15, start_time=2019-02-24 15:53:12.715672, end_time=2019-02-24 16:07:04.076986)>

# %%
# Visualise results
from pyabc.visualization import plot_kde_1d
for (k,v) in metrics.items():
    fig, ax = plt.subplots()
    for t in range(0, history.max_t+1):
        df, w = history.get_distribution(m=0, t=t)
        plot_kde_1d(df, w,
                    xmin=v[0], xmax=v[1],
                    x=k, ax=ax,
                    label="PDF t={}".format(t))
    ax.legend();
