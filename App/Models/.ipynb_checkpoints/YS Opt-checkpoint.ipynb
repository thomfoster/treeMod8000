# %%
import Main
from Analyser import *

# %%
modelName = 'Young_Shrub'

# %%
# Some PyABC magic to get our set of parameters
from pyabc import (ABCSMC, Distribution, RV, MultivariateNormalTransition)
import scipy as sp
import scipy.stats as st
import tempfile
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
def model(params):
    return Main.generate_and_analyse(modelName, params)

# %%
metrics = {  'section_1_slash':(10, 100),
             'section_1_slashr':(10, 100),
             'section_1_plus':(0, 180),
             'section_1_plus':(0, 180),
             'section_1_decay':(0, 1),
             'section_1_d':(0, 1),
             'section_1_h':(1, 20),
             'section_1_w':(0.1, 2),
             'general_thickness':(0, 5),
             'rule_1_0':(0,1),
             'rule_1_1':(0,1)
          }

# %%
prior = Distribution(section_1_slash     =RV("uniform", 10, 100),
                     section_1_slashr    =RV("uniform", 10, 100),
                     section_1_plus      =RV("uniform", 0, 180),
                     section_1_plusr      =RV("uniform", 0, 180),
                     section_1_decay     =RV("uniform", 0, 1),
                     section_1_d         =RV("uniform", 0, 1),
                     section_1_h         =RV("uniform", 1, 20),
                     section_1_w         =RV("uniform", 0.1, 2),
                     general_thickness   =RV("uniform", 0, 5),
                     rule_1_0            =RV("uniform", 0.5,1),
                     rule_1_1            =RV("uniform", 0.5,1)
                    )

# %%
abc = ABCSMC(model, prior, distance)

# %%
db_path = ("sqlite:///" + os.path.join(tempfile.gettempdir(), "test.db"))

# %%
target = model({})

# %%
target
# Out:
# {'parentAngle_mean': 35.35121935322306,
#  'parentAngle_variance': 24.08960449849906,
#  'length_mean': 1.4541861179269662,
#  'length_variance': 0.8140852517615195,
#  'verticalOrientation_mean': 74.71632067000091,
#  'verticalOrientation_variance': 36.08961835745618,
#  'horizontalOrientation_mean': 173.7238231214549,
#  'horizontalOrientation_variance': 99.71057076889478,
#  'q1_xyz': (32.80355415410715, 21.025415708987055, 41.65351545145833),
#  'q2_xyz': (42.72536068942685, 19.19813128138764, 51.224108924050824),
#  'q3_xyz': (18.42567898670766, 20.79567321995429, 16.164768386234996),
#  'xyz': (42.72536068942685, 60.775659016243026, 52.01219129418403),
#  'trunk_length': 10.0,
#  'totalBiomass': 193.79049043351665}

# %%
abc.new(db_path, target)
# Out:
# INFO:History:Start <ABCSMC(id=20, start_time=2019-04-16 16:56:59.309190, end_time=None)>
# INFO:Epsilon:initial epsilon is 21.828739391473373
# 20

# %%
history = abc.run(minimum_epsilon=0.5, max_nr_populations=13)
# Out:
# INFO:ABC:t:0 eps:21.828739391473373
# INFO:ABC:t:1 eps:14.627152715615935
# INFO:ABC:t:2 eps:10.57723315065451
# INFO:ABC:t:3 eps:9.544906159832262
# INFO:ABC:t:4 eps:5.457520170261491
# INFO:ABC:t:5 eps:5.067497635186067
# INFO:ABC:t:6 eps:4.373774832480728
# INFO:ABC:t:7 eps:3.5560492471935574
# INFO:ABC:t:8 eps:3.455692504900378
# INFO:ABC:t:9 eps:3.2894979799686284
# INFO:ABC:t:10 eps:3.1894086929263135
# INFO:ABC:t:11 eps:3.0867975502271587
# INFO:ABC:t:12 eps:2.9471166853038833
# INFO:History:Done <ABCSMC(id=20, start_time=2019-04-16 16:56:59.309190, end_time=2019-04-16 18:27:05.253952)>

# %%
# Visualise results
from pyabc.visualization import plot_kde_1d
for (k,v) in metrics.items():
    fig, ax = plt.subplots()
    for t in range(history.max_t, history.max_t+1):
        df, w = history.get_distribution(m=0, t=t)
        plot_kde_1d(df, w,
                    xmin=v[0], xmax=v[1],
                    x=k, ax=ax,
                    label="PDF t={}".format(t))
    ax.legend();
