# %%
import Analyser
from Analyser import distance
from main import generate_and_analyse

# %%
modelName = 'SymTree_Variance'

# %%
# Some PyABC magic to get our set of parameters
from pyabc import (ABCSMC, Distribution, RV, MultivariateNormalTransition)
import scipy as sp
import scipy.stats as st
import tempfile
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
metrics = {
    'default_w':       (0.2, 1.5),
    'default_decay':   (0.4, 1.0),
    'default_slash':   (0, 90),
    'default_slashr':  (0, 50),
    'default_plus':    (0, 180),
    'default_plusr':   (0, 50),
    'default_d':       (0.5, 1.0),
}

# %%
prior = Distribution(default_slash   =RV("uniform", 0, 90), 
                     default_slashr =RV("uniform", 0, 50),
                     default_plus    =RV("uniform", 0, 180),
                     default_plusr  =RV("uniform", 0, 50),
                     default_decay   =RV("uniform", 0.4, 1.0),
                     default_w       =RV("uniform", 0.2, 1.5),
                     default_d       =RV("uniform", 0.5, 1.0)
                    )

# %%
abc = ABCSMC(generate_and_analyse, prior, distance)

# %%
db_path = ("sqlite:///" + os.path.join(tempfile.gettempdir(), "test.db"))

# %%
target = generate_and_analyse({})

# %%
abc.new(db_path, target)
# Out:
# INFO:History:Start <ABCSMC(id=44, start_time=2019-02-26 08:03:32.960103, end_time=None)>
# INFO:Epsilon:initial epsilon is 18.599411506591395
# 44

# %%
history = abc.run(minimum_epsilon=1.0, max_nr_populations=15)
# Out:
# INFO:ABC:t:0 eps:18.599411506591395
# INFO:ABC:t:1 eps:11.806033157881801
# INFO:ABC:t:2 eps:9.382088157167749
# INFO:ABC:t:3 eps:7.45642536139193
# INFO:ABC:t:4 eps:6.240715026831861
# INFO:ABC:t:5 eps:5.402673843049377
# INFO:ABC:t:6 eps:4.647978465307186
# INFO:ABC:t:7 eps:4.071614742415131
# INFO:ABC:t:8 eps:3.7033699926620893
# INFO:ABC:t:9 eps:3.27667568488551
# INFO:ABC:t:10 eps:3.0219030871640573
# INFO:ABC:t:11 eps:2.6239025469137065
# INFO:ABC:t:12 eps:2.437451210979792
# INFO:ABC:t:13 eps:2.3375298130455753
# INFO:ABC:t:14 eps:2.1611800906032337
# INFO:History:Done <ABCSMC(id=44, start_time=2019-02-26 08:03:32.960103, end_time=2019-02-26 08:09:19.769250)>

# %%
# Visualise results
from pyabc.visualization import plot_kde_1d
for (k,v) in metrics.items():
    fig, ax = plt.subplots()
    for t in range(history.max_t, history.max_t+1):
        df, w = history.get_distribution(m=0, t=t)
        plot_kde_1d(df, w,
                    xmin=v[0], xmax=v[1],
                    x=k, ax=ax,
                    label="PDF t={}".format(t))
    ax.legend();
